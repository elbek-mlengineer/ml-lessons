# %%
mahsulotlar = ["olma", "anor", "banan", "qulupnay", "shaftoli", "apelsin", "uzum", "nok", "gilos", "ananas"]
mahsulotlar1 = {
    "olma": 15000,
    "anor": 16000,
    "banan": 17000,
    "qulupnay": 18000,
    "shaftoli": 19000,
    "apelsin": 20000,
    "uzum": 21000,
    "nok": 22000,
    "gilos": 23000,
    "ananas": 14000
}
print(mahsulotlar)
print(mahsulotlar1)
# Out:
# ['olma', 'anor', 'banan', 'qulupnay', 'shaftoli', 'apelsin', 'uzum', 'nok', 'gilos', 'ananas']
# {'olma': 15000, 'anor': 16000, 'banan': 17000, 'qulupnay': 18000, 'shaftoli': 19000, 'apelsin': 20000, 'uzum': 21000, 'nok': 22000, 'gilos': 23000, 'ananas': 14000}

# %%
def kopaytir(num1, num2):
  return num1 * num2

kopaytir(5, 8
)
# Out:
# 40

# %%
def sayHi(name):
  return "Hellooo " + name, "How are you?";

sayHi("Hacker")
# Out:
# ('Hellooo Hacker', 'How are you?')

# %%
friend1 = { "name": "Ali", "number": "+998901234567" }
friend2 = { "name": "Vali", "number": "+998901111111" }
friend3 = { "name": "Alijon", "number": "+998902222222" }
friends = [ friend1, friend2, friend3 ]
isFound = False
ism = input("ism kiriting: ")
for i in friends:
  if(i["name"] == ism):
    print(i['name'] + "ning telfon raqami: " + str(i["number"]))
    isFound = True
    break;

if not isFound :
  print("Foydalanuvchi topilmadi!")
# Out:
# ism kiriting: Ali
# Alining telfon raqami: +998901234567

# %%
def P(a, b, c):
  return "Uchburchakning Perimetri " + str( a + b + c ) + " ga teng."

P(2, 4, 5)
# Out:
# 'Uchburchakning Perimetri 11 ga teng.'
